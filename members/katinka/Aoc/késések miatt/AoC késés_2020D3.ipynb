# %%
with open('input_20_d3.txt', 'r') as fp:
    
    file_contents = fp.read().splitlines()

# %%
file_contents
# Out:
# ['..#...##...###.........#..#..#.',
#  '#.###........#..##.#......#...#',
#  '#.#.###..#.#..#.#............#.',
#  '.##............#......#...#.#..',
#  '..#..#.....##..##..##..........',
#  '...#...........###.#.##........',
#  '....#.#...#..#..##............#',
#  '....#....##...##..##........#..',
#  '.#..#..#....#...#..##.....##...',
#  '.#.###..#......####........##..',
#  '..#...###....#......#.....##.##',
#  '..#...#.......#......#..##....#',
#  '#...##....#.#..#.......#....#..',
#  '.#......#..#...........#....##.',
#  '.##.#......#.#.#.....##........',
#  '.....#.................#.#..#.#',
#  '....#..#........##......#..#.#.',
#  '..#...#..##.......#..##...#..#.',
#  '..#.......#.............#.#....',
#  '.#.................#.........#.',
#  '..#..#.#.#.#............##.#..#',
#  '.#.#.##.#.....#.....#..#......#',
#  '..#.#..#.#..........##........#',
#  '.........#...#.....#.#...#####.',
#  '##..#.....##.##........#...##..',
#  '.#.....#....##.#..#....##...##.',
# ...

# %%
a=len(file_contents)*7/31
a
# Out:
# 72.93548387096774

# %%
erdo=[]
for i in file_contents:
    erdo.append(73*i)
erdo
# Out:
# ['..#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#...##...###.........#..#..#...#.
# ...

# %%
erdo[1][3]
# Out:
# '#'

# %%
def beleszalad():
    a=3
    fa=0
    for i in range(1, len(erdo)-1):
        if erdo[i][a]=='#':
            fa=fa+1
        a=a+3
    print(fa)

# %%
beleszalad()
# Out:
# 205

# %%
def beleszalad_a():
    a=1
    fa=0
    for i in range(1, len(erdo)-1):
        if erdo[i][a]=='#':
            fa=fa+1
        a=a+1
    print(fa)

# %%
beleszalad_a()
# Out:
# 87

# %%
def beleszalad_b():
    a=5
    fa=0
    for i in range(1, len(erdo)-1):
        if erdo[i][a]=='#':
            fa=fa+1
        a=a+5
    print(fa)

# %%
beleszalad_b()
# Out:
# 85

# %%
def beleszalad_d():
    a=7
    fa=0
    for i in range(1, len(erdo)-1):
        if erdo[i][a]=='#':
            fa=fa+1
        a=a+7
    print(fa)

# %%
beleszalad_d()
# Out:
# 79

# %%
def beleszalad_e():
    a=1
    fa=0
    for i in range(1, len(erdo)-1):
        if i%2==0:
            if erdo[i][a]=='#':
                fa=fa+1
        a=a+1
    print(fa)

# %%
beleszalad_e()
# Out:
# 33

# %%
szam=205*87*85*79*33
szam
# Out:
# 3952146825

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=978e47b7-a961-4dca-a945-499e8b781a34' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
