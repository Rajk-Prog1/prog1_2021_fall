# %%
with open('input_21_d5.txt', 'r') as fp:
    
    file_contents = fp.read().splitlines()

# %%
file_contents
# Out:
# ['456,846 -> 221,846',
#  '980,926 -> 73,19',
#  '682,930 -> 562,930',
#  '766,592 -> 274,100',
#  '247,685 -> 247,21',
#  '106,800 -> 635,800',
#  '953,340 -> 135,340',
#  '293,223 -> 293,12',
#  '454,196 -> 454,463',
#  '886,766 -> 164,766',
#  '592,590 -> 192,590',
#  '436,982 -> 436,545',
#  '731,571 -> 420,260',
#  '741,11 -> 466,11',
#  '727,541 -> 579,541',
#  '341,553 -> 25,553',
#  '942,470 -> 942,196',
#  '203,600 -> 203,647',
#  '965,595 -> 949,611',
#  '554,306 -> 554,401',
#  '902,438 -> 902,728',
#  '864,609 -> 525,270',
#  '187,790 -> 187,323',
#  '956,950 -> 427,950',
#  '847,554 -> 422,554',
#  '935,900 -> 701,900',
#  '192,854 -> 866,180',
#  '512,946 -> 543,915',
#  '978,979 -> 491,979',
#  '708,61 -> 708,878',
#  '738,508 -> 282,52',
#  '23,25 -> 841,843',
#  '204,750 -> 204,797',
#  '703,500 -> 703,419',
#  '14,311 -> 694,311',
#  '646,301 -> 785,301',
#  '397,168 -> 439,168',
#  '680,931 -> 561,812',
#  '540,448 -> 90,448',
#  '706,668 -> 91,53',
# ...

# %%
koordinatak = []
for i in file_contents:
    nyilas = list(i.split(' -> '))
    majdnemjo = []
    for l in nyilas:
        par = list(l.split(','))
        majdnemjo.append(par)
    marjo = []
    for k in majdnemjo:
        for m in k:
            marjo.append(int(m))
    koordinatak.append(marjo)

# %%
koordinatak
# Out:
# [[456, 846, 221, 846],
#  [980, 926, 73, 19],
#  [682, 930, 562, 930],
#  [766, 592, 274, 100],
#  [247, 685, 247, 21],
#  [106, 800, 635, 800],
#  [953, 340, 135, 340],
#  [293, 223, 293, 12],
#  [454, 196, 454, 463],
#  [886, 766, 164, 766],
#  [592, 590, 192, 590],
#  [436, 982, 436, 545],
#  [731, 571, 420, 260],
#  [741, 11, 466, 11],
#  [727, 541, 579, 541],
#  [341, 553, 25, 553],
#  [942, 470, 942, 196],
#  [203, 600, 203, 647],
#  [965, 595, 949, 611],
#  [554, 306, 554, 401],
#  [902, 438, 902, 728],
#  [864, 609, 525, 270],
#  [187, 790, 187, 323],
#  [956, 950, 427, 950],
#  [847, 554, 422, 554],
#  [935, 900, 701, 900],
#  [192, 854, 866, 180],
#  [512, 946, 543, 915],
#  [978, 979, 491, 979],
#  [708, 61, 708, 878],
#  [738, 508, 282, 52],
#  [23, 25, 841, 843],
#  [204, 750, 204, 797],
#  [703, 500, 703, 419],
#  [14, 311, 694, 311],
#  [646, 301, 785, 301],
#  [397, 168, 439, 168],
#  [680, 931, 561, 812],
#  [540, 448, 90, 448],
#  [706, 668, 91, 53],
# ...

# %%
len(koordinatak)
# Out:
# 500

# %%
xhossz = 0
for i in koordinatak:
    for k in i:
        if k>xhossz:
            xhossz = k
xhossz
# Out:
# 990

# %%
from itertools import repeat
zero = []
zero.extend(repeat(0, 1000))
tengely = []
tengely.extend(repeat(zero, 1000))

# %%
len(tengely)
# Out:
# 1000

# %%
for i in koordinatak:
    if i[0]==i[2]:
        nagyobb = 0
        kisebb = 0
        if i[1]>i[3]:
            nagyobb = i[1]
            kisebb = i[3]
        else:
            nagyobb = i[3]
            kisebb = i[1]
        for k in range(kisebb, nagyobb+1):
            tengely[i[0]][k] = tengely[i[0]][k]+1
    elif i[1]==i[3]:
        nagyobb = 0
        kisebb = 0
        if i[0]>i[2]:
            nagyobb = i[0]
            kisebb = i[2]
        else:
            nagyobb = i[2]
            kisebb = i[0]
        for k in range(kisebb, nagyobb+1):
            tengely[k][i[1]] = tengely[k][i[1]] +1

# %%
kettesek = 0
for i in tengely:
    for k in i:
        if k==2:
            kettesek = kettesek +1

# %%
kettesek
# Out:
# 1000

# %%
import re
import numpy as np

# %%
with open('input_21_d5.txt', 'r') as f:
    lines = f.readlines()
    lines = [entry.strip() for entry in lines]

max_x = 0
max_y = 0
for line in lines:
    x1, y1, x2, y2 = [int(entry)
                      for entry in re.sub('[^0-9]', ' ', line).split()]
    max_x = max(max_x, x1, x2)
    max_y = max(max_y, y1, y2)

print('max x', max_x, 'max y', max_y)
grid = np.zeros((max_y+1, max_x+1), dtype=int)
# Out:
# max x 989 max y 990

# %%
def enter_line(grid, x1, y1, x2, y2):
    if x1 == x2:
        for y in range(min(y1, y2), max(y1, y2)+1):
            grid[y, x1] += 1
    if y1 == y2:
        for x in range(min(x1, x2), max(x1, x2)+1):
            grid[y1, x] += 1

for line in lines:
    x1, y1, x2, y2 = [int(entry) for entry in re.sub('[^0-9]', ' ', line).split()]
    enter_line(grid, x1, y1, x2, y2)
print('score', (grid >= 2).sum())
# Out:
# score 5280
