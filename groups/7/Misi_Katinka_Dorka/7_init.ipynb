# %% [markdown]
# ## 1. feladat: írjatok egy függvényt, ami:
# - egy string-et fogad paraméternek
# - **kitörli belőle az összes abc-ben szereplő** karaktert, tehát csak a **speciális karaktereket hagyja meg**
# - és ez a módosított string a visszatérési értéke

# %% [markdown]
# **ez lesz a függvény paramétere (futtasátok a cellát Ctrl + Enter-rel)**

# %%
input_string = open('input_string.txt').read()[:-1]

# %%
input_string = open('input_string.txt').read()[:-1]
def not_abc(input_string):
    return list(input_string)
print(not_abc(input_string))
# Out:
# ['d', '%', 'f', '(', 'a', '/', 'x', 'y', '(', 'l', 'e', '%', 'd', 'c', 't', 'g', '(', 'b', '&', 'd', '(', 'y', 'w', '(', 'm', 'z', '(', 'z', '.', 'o', 'e', '(', 'b', '+', '(', '%', 'p', 'j', '(', 'a', 'g', 'a', '+', '(', 'c', 'y', 'c', '.', 'a', '(', 'c', 'l', 'e', '+', 'o', '(', 'j', '/', 'v', 'o', 's', '(', 'x', '\n', 'j', '(', 'r', 'v', '(', 'd', '(', '\n', 's', '(', 'o', '\n', 'y', '(', 'v', 'r', '(', 'p', 'j', 'n', 'h', '(', ' ', 't', 'o', 'z', '(', 'v', 'n', '-', 'm', '(', 'f', 'b', 'i', 'p', '&', 'u', 'b', '(', '\n', 'a', 'o', 'g', 'y', '(', 'r', 'k', 'f', '*', 'g', 'z', '(', '(', 'd', 'k', '(', '(', 'p', 'l', 'g', 'x', 't', '(', '%', 's', 't', 'w', 'r', 'n', '/', '/', 'k', '/', 'i', 'k', '%', 'k', 'k', '/', 'm', 'o', '\n', 'x', 'b', 'a', '*', 'i', 'a', 'b', 'x', '-', 'w', '*', 'a', 'j', '*', 'z', 'z', 'y', 'f', '*', 'q', 'r', 'r', 'p', 'f', 't', 'u', '\n', 'n', 'a', 'l', 's', '+', '.', 'a', '+', 'g', 'r', '+', 'h', '+', 'j', 'y', 'm', '.', 'l', 's', 't', 'g', 'x', '+', '+', 'x', '+', 'w', '*', 'h', 'u', 'a', '+', 'z', '.', 'o', 'f', 's', '/', 'y', 'i', 'w', '@', 'g', 'v', 'v', '(', 't', 'u', 's', '.', 'z', 'e', '/', 'j', 'n', 't', '\n', 'w', '*', 'c', 'l', '\n', 'd', 's', 'e', '*', 'p', 'u', 'd', 'o', '.', 'w', '(', 'e', 'u', '&', 'b', 'u', '/', 'k', 'o', '%', 'p', '/', 'x', 'l', ' ', 'b', 'q', 'c', 'g', 'i', '+', 'm', 'n', '&', 'r', 'g', '*', 'q', 'k', 's', 'j', '.', '*', 's', 'b', 'd', 'y', '*', 'e', '(', '\n', 'r', 'r', 'h', '/', 'p', '%', 'k', '/', '-', 'q', 'm', '(', 'i', 'j', '-', '(', 'e', '@', '-', 'b', 'k', 'o', 'c', '\n', 'l', 'h', '(', 'g', 'l', '\n', 'q', 'x', '(', 'k', '@', 'v', 'u', 'r', '(', '\n', 'q', 'f', '-', 'v', 'w', 'q', '-', 'o', 'f', 'r', '-', 'u', 'c', 'n', 'b', '+', 'v', 'f', '(', '*', '(', 'u', 'y', '&', 'f', 'v', 'r', 'z', '(', 'i', 'x', '*', 'p', 'g', 'a', '/', 't', 'q', '(', 'f', 'q', '(', 'i', 's', '.', 'o', 'o', 'r', 'x', '-', 'g', 'b', 'r', 'z', '@', 'k', 'v', 'l', '(', '%', 'x', 'p', 'f', '(', '+', 'u', 'b', '/', 'r', '+', 'z', 'v', '/', 'p', 'v', 't', 'n', '*', 'k', 'q', 'q', '*', 'n', 'i', '+', 'j', 'y', '/', 'v', 'v', '@', 'g', 'd', '/', 'f', 'n', 'x', 'j', '*', 'a', '/', 'v', 'k', 'o', 'k', '@', '(', 'e', '@', 'r', 'o', 'k', '(', 'h', '%', 'o', '(', 'e', '.', 'x', 'u', '/', 'z', 'q', 'd', ' ', 'g', '-', 's', 'f', 'h', '&', 'q', 'o', 'r', '(', ' ', 'f', '-', ' ', 'd', 'e', 'd', 'y', 'u', '-', 'd', 'n', 'd', 'h', '*', 'k', 'b', '(', 'q', 'j', 'y', 'd', 'b', 'z', ' ', 'o', 'w', 'v', '(', 'k', 'y', '&', 'f', 'n', '(', 'd', '(', 'f', '-', 'c', 'l', 'x', '&', 'y', 'n', 'n', '-', '+', 'v', '-', '-', 't', 'q', 'p', '(', 'b', 'x', 'w', '(', 'b', 'g', 'l', '-', '.', '-', 'c', '*', 'k', 'f', '-', 'm', 'o', '.', 'i', '-', 'f', '@', 'p', 'i', '-', 'd', 'v', 'u', '+', 'k', 'y', '-', 's', '\n', 'k', 'r', 'o', '-', 'o', '/', 'l', 'p', '-', '%', 'f', 'w', 'g', '-', 'l', '.', 't', 'i', '-', 'k', 'i', 'g', 'u', '(', 'f', 'i', '-', 'l', 'e', '.', 'x', 'g', 'r', 'x', '-', 'n', 'j', 'h', 't', '.', 'c', 'd', 'o', '-', 'm', 'p', 't', 'l', '%', '\n', '+', 'a', 'm', 'p', '(', 'i', 't', ' ', 'z', '(', 'y', 'j', '\n', 's', '(', 'a', 'i', '@', 'm', 'j', 'f', 'i', 't', '(', 'r', '(', 'y', '(', 'q', '\n', 'y', 'k', 'q', 'i', 'i', '(', 's', ' ', 'a', 'o', 'n', 'v', 'r', 'z', '(', 'b', 's', 'g', '\n', 'l', 'h', '(', 'm', 's', 'i', 'z', '.', 't', 'd', 'i', '(', 'o', 'n', 'r', 'v', '.', 'z', 'x', 'u', '(', 'v', 'l', '%', 'm', '(', 'r', '%', 'r', '(', 'v', '*', '(', 'n', 'j', 'c', 'o', '+', 'f', '(', 'q', '&', 'b', 'w', 'l', 'a', 'o', '(', 'r', 'c', '*', 'b', 'b', 'z', 'd', '(', 'n', 'z', 'b', '*', 'u', 't', '(', 'g', 'q', 'e', '&', '(', 'a', '.', 'm', 'a', '(', 'x', 'i', 'f', '&', 'z', '(', 'k', '(', 'y', 'x', 's', 'l', 'n', '(', 'i', 'n', '(', '(', 'm', '@', 'r', '(', '@', 'q', '-', 'r', 'x', 'w', 'u', 'e', 'r', ' ', 'w', 'i', '/', 'g', 'n', 'x', '.', '*', 'e', 'd', '-', 'x', 'l', '+', '-', 'c', 'o', 'f', '+', 'i', '*', 'h', '/', 'd', 'a', '\n', 't', 'f', 'z', '/', 't', 'i', 'p', ' ', 'k', 'x', '(', 's', 'z', 'e', ' ...

# %%
input_string = open('input_string.txt').read()[:-1]
abc=["a", "b", "c", "d", "e","f","g","h","q","w","r","t","z","u","i","o","p","s","j","k","l","y","x","v","n","m"]
def not_abc(input_string):
    for i in abc:
        input_string=input_string.replace(i,"")
    return input_string

# %%
print(not_abc(input_string))
# Out:
# %(/(%(&(((.(+(%(+(.(+(/(
# (((
# (
# ((( (-(&(
# (*(((((%///%/
# *-***
# +.+++.+++*+./@(./
# *
# *.(&/%/ +&*.**(
# /%/-(-(@-
# (
# (@(
# ---+(*(&(*/((.-@(%(+/+/**+/@/*/@(@(%(./ -&( - -*( (&((-&-+--((-.-*-.-@-+-
# -/-%-.-(-.-.-%
# +( (
# (@(((
# ( (
# (.(.(%(%(*(+(&(*(*(&(.(&(((((@(@- /.*-+-+*/
# / (-(/-
# -%- %
# (+(
# /
# /&((*&( (((
# /+*+/(/&(&(+(+(
# -@(
# (/-@-
# -+(/(-(@- (*/@(./((@(*/+(
# -&-@/(-/- - (--&(&(*-@-@- -%-%-%-+-
# -+-&-&---.-%- ---*- -.
# +(
# (/(+(-(+( (
# (%(@(*(.(*(*(/(-(%(+(%((( -*-@((/%*+*/( -/-%&*%%%(%@%/% -+%.%
# --(+/*-@/*/ / (/*-/*(*/((
# /
# /./././+//(*(-(+(/(+(@(@(-(%(/(
# (+(&(*-(-+-
# ( ( (+( (.-+-+-@- ---*-/-
# -.-+-.- -*-
# -@-(-(-%-*-&-@
#  (
# (@( (-(-(&(%(((.(.( (/(.(.((( (((+(&%+--(//.*+(
# (/(
# *//%(((--@%(-%- - ( ((/&/
# *%/&/@***%/&*(*%/&/@/./@/%/@/&/+/@/
# /&(-/%/*(&/&(-(.(*/
# /
# /*/ /*(+(-( (@(@(*/%(&(%(*-.-(-*-%-@-.-&-
# -/-%-.-%---.-%-+- -+
# *(.(&(
# (+(-(+(.(+(+(
# (@(+(.(((-/./.*&(
# % /&+%+@*./@/%/@(((.(*/ /@(&/ /-/(***(*(**+
# *
# *-*+*
# *-*&*/*-*@* ***////&/+/-/*/
# (@(+(@(//.(.(%(.(*/
# /
# /(/
# /&/-/*/+(
# /
# ///&/-(@-&-%-.-&-
# -(-+---(-%-%---(- -@-@-
# -.
#  (-(&( (-(&(@(@( (((/(-(
# /@*
# * /&/@/%(@.@+&*@*(/*(/-+(.(
# ( /-/-/ ***&+
# *@+.+
# +(+**(*.*%*@*/*@*(*&*%*+*.*(*&/(/-/+/@/@/
# /((@/-(((-(-(+((//(
# (+/+/.( /(/+(&/(//( (+/(( ---
# -*(/-/-+-%-/-
# -+-@-+-@- -
# -.-
# -%
# /(@(@(-(*(((+(.(&(/(-(/(./+/%/(*%+
# +
# */*
# *.*+/%/%/(///+///+* *%*@*+*(+*+.+/+&+
# +.+
# *%*(*** *%*.*+*-*@**/+/ /+///(/-( /@/(//(&( (*(@(((-((/%(-(-(*(+(((@(*(/(%/
# ( (%(
# (
# (@-(-%-+- -/-&-+-.-/-(-*-&-.-
# -/-@
# +( (*(/(-(%(*(*(.(*(
# (-/&***
# *+* +.* /*/+*-* *./@/&*@*&*
# * +/+.+++++/+
# +(+/+/+
# + +.++*.* *-*@*@* *-*+*%/(/ /@/+/(/@/*/.(
# ///%(
# -/(.-((+(-(-(.(&(+(((./%/
# /+(+(
# ((-*-/(@-@-+-@-%---&-+- -.-(-@-*-/- -/- -/
# @(*(-(-(@(((.(.(+(@(%(-*@/@/**+*/+&//*%+/*-/%*(**+/+.+.+++
# +&+/++*&+++-+-+&+
# +&+ +(+
# ***.***%*
# *(*@*&*//+/%/ /(/./
# /
# /./-/ (@(-(
# (%(/(%-./ (-(/(.(+(+- -+-+-+-(-
# (&(@((---@---%- -/-.-.-@-*-*-%-+- -.-.-(
# +(.(%(@(
# (
# (+(.(@((( (@/*/(*@*.* *(*.+@*-*.+(+
# +%+(+-+@+@.+.-+&+*+&+*+%+@+.+-+-+.+ +@*&*****%*/*%*&*+/(/&/
# **/@/+/
# /-(./ /
# /
# (@(*(----.(&(-(
# (
# -+-&-(- -.-
# -%-*-+(+(+(
# -*-+- -%-&-&-*-.-%-.-+-.-*-@-
# -%--
# &/+(&(/(.( (
# (
# (@(.(
# (*(-/(///@/@/@*
# *-*/*-+@+-+ +
# +..@+%.&+%+
# + +@+(+&+%+.+/+&*++.+&+%+&*.*
# *%*
# *+*/*/*/*(///%/(/+/(/+/
# /&/+(+( -(-.-&- -*-%-
# (&-*%+%%%@- ---+-/(
# (@(
# (--@-.---*-@-/-/-@-*-+-/-/-(-+-%-(
# -/%(*(&(*(%(((-(/(/(&(&(-/%/ ///+*
# *@*/*%*.+++@+(++././+&+/+*+@+&+-+
# +&+(+
# *++ * **+
# +(+ *@*/***.*-*****(*+*%* /%/(-%( -+(%(&(/(+(.-(- -*-+-.-.-@(&%(-@%%%-%@- -(-
# -+- %-- -%(--
# -&-.-%-/-&-&-*-%-%---/--
#
# /%(
# (%(
# (+(/(
# (+(+(.(@(((+/// *@(+(%/(*++%+@+-+-.@+@+..++@+%+.+/+ +
# +(+/+/*+***-+(*
# +(+(+
# ***%*+* *
# *-*+/@(.-
# -+%%%%%&%@- (&- (((
# ( -+(
# - (&-/-%-%-.&/%-( -((&(--.-(-(-*-@-(-(-(-.-*-.-@- --- -@---@-@-%
# (/ /.( (%(/(-(+(((/(&(*(@(-(//&/
# /+((*-//*%+ +-/@+*+%+
# +&++++.(+@+&+-+@+&+
# +
# + +(*
# */+@+(+%* *&**//(*(-%(%
# &/%&-%-%-+-.(--@(*-((@-(-*( -&-&(&(+-/-(%&& &&%.%
# &+&@%.%&%.%
# /&(@-%(@-.-.-(-+-&-@-/-&- -.-*-&
# */%/%///+/./(/*/&/((&/*(.(((&(%/(/
# (+/&*.+(+&*./-(*-*( /((@*%+ *.+-+.*
# +**
# */+%*
# */*./*+&+*/.( ( --%@% %--*( /(/
# / /&(((((*- -%-+-@(+(-(*(-(((
# (
# (%%/%&&&&
# &@&@%*&.& &-%.-@(((--@((- -
# -
# -
# -
# -&- -/-&-/-
#
# %/@(//@/*(%/ /@/ (*( ( (*( (//./*(@(.-((&+(+
# /&/
# /.* /*(*//(%-/-*(@/-( *.*+*&+*+ **/+(%((/./-(.--%&--%.-//-((%+@/&/@-& %*%/(((/-.( (
# (*(@(((/(
# (/-&( %-%%&-&.&&%
# @(&.&(%.-@(@((-/-.- (
# (-(@-*-*-@-
# ---@-@
# &/+/./(/*/ /+/ /+/%/./(/+/-/
# ( (+(-(@-&/+*(+ *
# */+++
# +(+*+@*//@(/-
# -+-
# % %/- +@+@+(*
# *%/&(
# -
# %(%%-&(@/+(*/**
# /%-
# -%- /@/--+-@-
# %&(*(@/ /@( (&( (/(.(&-+@ &(%
# &@&+-%(*/
# (@(@/--%-.---
# ---*(--
# ( -%---
# -*(@
# -/-///-/%(./+/*/*/(/ ///@/&(&(((-/%(.%+/****@*
# +
# +(/
# %@(+*(+/-*-(-*%%(.-/(///+
# +(+%+&*(*%/ (%---&(&(&-.(
# (@/-(@/+/+(%(%(*(*(%/@( (%/+/@/*(-(.(-(*(%(*(.-%%%&+&.%.-@(%/(/%-*( -&-*---@-*-(-@-/---&-.-&---
#
# ./-/@/
# /%/%///*/@///.(./%/-(*(*(
# *.*
# ( ((**+(+++(*%/ +++&+&*(*/*
# /&/
# /%(//.*@* +%+
# +&*-*+/*(
# -%-/(((*(
# (+(
# /*/.( /(/+(-(@(%/%*+*//(/&/
# /@(+(.-&(/(%(*(*(%-%-(-%%&( (@((/%- - -%-@(.-@-
# ---@-&(--%(
# -&-&-*
# //&/*/@/ /./@/+/%/+(*/ ( (-(/(.(/((*(*.*+(%+++(+&+*+(+
# +++-++*+*&/ (+/
# +-+@*-+@+++ *.*@/.(&(.(+(*(/(.(+/(/// /@/./
# /.*
# *&* *+/././ (-(.(((*( (
# -@(&(+( -*-&%/%
# % (./.(@-*//-&-%-
# -+- - -@-%(.(&-&(+(+-/-%
# %/&/&/%/
# /&/-/
# /%/./@/%/.(
# /.(-(
# (@(+/
# +@+%*&+%+++/+%*
# * * *
# +-+%+&+%+&+(+.+.+.+
# +@*****(/@/@(-(+(.(%(
# (-///(/
# /@*&*+*@*(*%* / /
# (((&( (@(.(+(*(&(&( -/- -*-/%//(**/
# /*/*-
# -/-&( (
# (&-@-*(@(
# (-(
# (@(*-(-
# -/@/(/&/+///%/@/*/%(-/*(&(-(&(&(+(
# ( (*(%+ +@*@+%+++.+.+-+@+
# +++/+(+ +/+ /&+@+*+/+/+&***-/&(+-(-((&/@((-/(-(./*/./%*(*+*
# *@/ /*/%(((/( (/(*(
# (.---.-/-.-(-(-&-
# /
# *./%/.(@- -/-%-/-.(@( -.(*-%- (@-
# -(-(-
# @///@/%/*/*/@/./@/@/ /&/+/&(-/((+( (/(+( (@+ *
# +-+ +/+.+.+-+
# +@+/+/+*/-(@*(+
# +&.*+++++%/%(*(@(// /
# (((
# -(%@(.-(-&(*/(/-/&/-/-/.( (.(((*(.(.( (&(&-%---+%*-.- (%/-(+( - -%-+---(-((*(.-%(@-&-@(%(
# -@-((&-&
# @/ ///&/
# /
# /*/(/%/*/&/(/-/&(-/
# /
# (/(
# (
# (%(%/++%+%+&+%+/+.+/+/+-++*&/@(+(%+&*.*
# *
# * * /*(/--%-%&% -@--%+(&(%(.(
# /@(%(&/ /
# /*/.(+(&(
# (.(.(((((.- -/%/-&- -(-(-/%@-&(-( (%(+( -&(--
# -*(((/(/((-&--(%( -(-%(-
# (/./
# /./
# ///*/./@/-///(/-///@/((.//(+(%(.(./.+*+&+%+.+-+-+.*.* *
# /((/(
# +%+ +@+ +
# *.++*
# /.*+/(/.(%(@(&/*(+(/(@( (-(/(.( (((-/%(-(((*-@-((@( -@-%-/---@- -@-+%@-@-/(-(@(+(-( (*-%(
# (
# - (&-@(
# (.((-.(-(+(-(@
# +/ /(/*///// /(/+/&/+(%(*( /%(/(.( (*( (
# (@(&(+/++*+.+@+&+%* * /&(*(@+*+/+ +%+
# + +(+/*%/ /@+-*+/.////( (%(&/&(%(((
# -
# -*-.-@-+///-/@(+(((%(&(-- -
# -+-(-@-@--%.---*(%(%(@(&((((( (-(.(-(*(%(@--(--@-%-
# (&(-
# -/%/./-/*/
# /%/ /
# /%/+/%/*/(/ (%(
# (-(%(
# (/(.(*(
# (%(&+.+(+@+++**+/@(&+(+ +.+.+&+++ +(+(+&/+*&*-+@*@/((@(+(.(*-/-+-+%+%-%--+(
# (%***//((+-@-&(
# (@(%-&%*-&-&-(%-%%-+-*( (*(.(&(
# (.(&(((&((( (@( (((--(--(%-/-@
# @/./+/@/&/(/*///
# /+///+/ //(.( ( (+(*(@(/(((-( (
# ( /@+*+&+*+
# +.*&/ +.++*(*%*-*
# /%/%/@/ /./@/ -@-@--%/%.%.-*(*(-(((+(*(+(*((/&*-///-(@- (@(+(/(
# %.% -%-
# -*%(-(((-.(-(((@( (&(.(&(
# (+(+(-(+(/(*(*(*( -&(*-*
# .///*/&/./%/(/-/-/@/*/((./+/@/-(./.(/(/( (%(/(.(/(+(@( +@+&+%+&+(*@/
# *
# / + + +*+%+(+.+(+&*(*.* *+/./// (%(.(*(.(+(.(&(
# /*///+/@/.(@-&(.//(-(@%/-
# -%-(-(-+-%(-(.**&+@/%%(
# (-(+(%(/(/( (%(
# (-(&( (@(
# (--+-
#
#  /&///./////@/(/
# / (-(@(./ /(/&(*(.(&(%(
# (*(@(%(@(@(*(.(*+ +++(+-+-* *++++/+%+
# +/+-+@***/*
# ***//-*@(%/ (
# (-( (+(/(.(//+( /
# / /
# (&((( /&/((@---.-+-@%&- %-(((@/@***
# @&@(@
# --(&(/( (-(@(*(+(/(/(/( (.(+(
# -.
# -/(/
# /-/%///
# /(/
# ///.///-/@/@/*(
# (
# (.(((.(
# (((((
# (.(-( (@(%+%+
# +&+ *@**+*+(+.+&+&+*+*+(+**(/%/%(+/(/ /*/./(/+/
# /@/*(-(.(*( (-(@(&/.//((((-+-@-%-&-/%+%@((- *(* */*%@*@.@.@.@&(+(
# (((.(&(-(%(%(@(/(%((-/(-
# .///*/((
# /
# /*/./-/(/
# /.(+/./@/&/
# /*(.(*(%(&(@( (-(/(+(((-(%(.*%+/+++
# +/+++
# +.+-+/+@+-+
# + +@*+* *
# *%/+/(/-/-/(/*/.(+(-( (@-+-%-%/./
# /&(-- %
# -+-
# %@%@&((&* *@*.*.* /.@ @(@*@-@ @@@@%
# (@(((@(-( (((-( (+(*(*
# +///
# /*/+/*/@/(/
# /&/%/-/
# ///*/&/-/ /%(((-/&(/(+(*(%(&(-( (+(.(%(
# + + *(*-*.+.+-+@+&+ +@+ ***.+%**/ /@///%/&/
# /*(+-%-(-/%+-/(&(*(+(&(&-.-(-*--%@%@*@* ***(*/***(*&@/@.@/@@@
# @%@+@@@ @+@(- (%( (
# (+(%(
# (
# (+
#  /%/&/(/&///&/&/+/+/
# /(/((&/
# /
# /./*/*/(/+/*/
# /-///./*/@/
# (+( (@&+  *(****+ +/+(+*+%*&*%*
# *@*.*&*&///(/////*(((/---&%.%
# (/(*(*(+/+(-((-&-&%-%.(-*
# *&*
# ***&*(*./ @
# @(@-@.@ @(@/@/@%@(@&@
# @-@+@*@.@
# &/( (+(.
# +/ / /
# ///././(/-/
# /./(/&/*/(/ /
# ///&/./&/
# /@//(/%-&/@%@*&.&&@&(+
#   .++%+/+*+-+*+(*&*/**/ /-/@/@/%/-/
# (&( -/%/-%(&/%(/(+(+/
# /
# (.- -/% %(( *(++* *%*%*-*&***
# @(@+@@@
# @ @
# @%@@@-@+@ @-@/@.@+@(@ @(@+@%@(@.
# %/./-///*/*/ ///./&/+/&/(/(/%/&(%%
# &-&-&*@ @.&*@*@%&/&&&-%&&.@*.% @ . . (.&+.+.+@+&+@+(+ +@+/+-+&+&*
# * /%(%(&/&/*/-/((%/
# (+(/-@-%-/%+*%*
# +(+
# *%*
# *
# *%* *+/.@*@(@/@+@&@(@(@%@+@-@%@%@/@ @&@.@(@ @@@*@&@%@/
# ./+/ /(/.///+/+( %
# &-@&@*&+@(@%&-@%@-&
# @/&+@/&@&%&&& &.&+@&@
# @& + . / (   ( /./+@+(+ +
# +.*(*@+(+
# +%+ *.***+**///-/ (((%(((
# -@-// *.+@+%+
# +.++*%*(*@*(*+/ @ @%@/@/@
# @
# @.@/@-@*@+@.@@@ @*@ @.@.@/@
# @ @*@ @@
#
# /(/ %&&(&/&
# &%&-&(&.&*&%@&&*&&@ @*@%&%&*&
# &*%&&&%
# %-&(@&@
# @&*
#  ( ( -
#  @ & -
# +//@+.+(+++ +/+*+&+%***.**///
# /-(.(%(&(.*.*(+/+*+@+ +-+@+.+&+/*%*+*@-+@/@
# @&@&@-@%@*@*@*@@@.@+@@@ @-@-@
# @&@%@*@(@
# @
# @%@*
# *&@& @ &-&/&
# &&&/&*&/&(&
# &-&(&*@@&@&
# &&&*&%&@&-&/%%@(@+@.@%* .- % *
#  - % ( ( - ( .. +@((///@*-*+*(*
# +@.*.+.%...-.@.%.*...@.++++-+
# +++++ +
# +.+ *-*-&/@.@ @ @&@.@-@-@.@&@(@-@&@*@*@/@
# @/@/@+@
# @/@+@*@/@/@/
# +&/&&&%%
# &*&-&*&.&(&+&%&/&*&
# &%&(&&@.@-&
# &+&%&/&.&.@@@+@*++. .+ % ( % * (
#
#
#  +/ /-/ .* *..+* (
#
#  @ & ( + + /...
# .-.+.++%+@+.+-+++-+ +*+(*+&/@%@.@%@&@/@-@%@.@/@+@.@ @+&
# &+@(@&@@@ @%@&@&@*@%@ @&@

# %%
a="Hello World"
def split(a):
    return list(a)
print(split(a))
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd']

# %% [markdown]
# ### itt tudjátok leellenőrizni, hogy jó-e a függvény, amit írtatok
#
# - az own_func helyére írjátok be a saját függvényetek nevét
# - a p helyére tetszőleges paramétert, amivel ellenőrzitek a függvényt
# - futtassátok a cellát Ctrl + Enter-rel!

# %%
from func import check_rem
check_rem(not_abc, input_string)
# Out:
# Gratulálok! Megoldottad a feladatot!

# %% [markdown]
# ## 2. feladat: írjatok egy függvényt, ami:
# - egy string-et fogad paraméternek
# - **az összes '+' jelet ','-re, az összes '-' jelent pedig '#'-re cseréli**
# - és ez a módosított string a visszatérési értéke

# %% [markdown]
# **a függvény paraméterét az első csapattól kapjátok meg (futtasátok a cellát Ctrl + Enter-rel)**

# %%
input_string = not_abc(input_string)

haha=["+","-"]
def cucc(input_string):
    for i in haha:
        if i=="+": 
            input_string=input_string.replace(i,",")
        elif i=="-":
            input_string=input_string.replace(i,"#")
    return input_string

cucc(input_string)
# Out:
# '%(/(%(&(((.(,(%(,(.(,(/(\n(((\n(\n((( (#(&(\n(*(((((%///%/\n*#***\n,.,,,.,,,*,./@(./\n*\n*.(&/%/ ,&*.**(\n/%/#(#(@#\n(\n(@(\n###,(*(&(*/((.#@(%(,/,/**,/@/*/@(@(%(./ #&( # #*( (&((#&#,##((#.#*#.#@#,#\n#/#%#.#(#.#.#%\n,( (\n(@(((\n( (\n(.(.(%(%(*(,(&(*(*(&(.(&(((((@(@# /.*#,#,*/\n/ (#(/#\n#%# %\n(,(\n/\n/&((*&( (((\n/,*,/(/&(&(,(,(\n#@(\n(/#@#\n#,(/(#(@# (*/@(./((@(*/,(\n#&#@/(#/# # (##&(&(*#@#@# #%#%#%#,#\n#,#&#&###.#%# ###*# #.\n,(\n(/(,(#(,( (\n(%(@(*(.(*(*(/(#(%(,(%((( #*#@((/%*,*/( #/#%&*%%%(%@%/% #,%.%\n##(,/*#@/*/ / (/*#/*(*/((\n/\n/./././,//(*(#(,(/(,(@(@(#(%(/(\n(,(&(*#(#,#\n( ( (,( (.#,#,#@# ###*#/#\n#.#,#.# #*#\n#@#(#(#%#*#&#@\n (\n(@( (#(#(&(%(((.(.( (/(.(.((( (((,(&%,##(//.*,(\n(/(\n*//%(((##@%(#%# # ( ((/&/\n*%/&/@***%/&*(*%/&/@/./@/%/@/&/,/@/\n/&(#/%/*(&/&(#(.(*/\n/\n/*/ /*(,(#( (@(@(*/%(&(%(*#.#(#*#%#@#.#&#\n#/#%#.#%###.#%#,# #,\n*(.(&(\n(,(#(,(.(,(,(\n(@(,(.(((#/./.*&(\n% /&,%,@*./@/%/@(((.(*/ /@(&/ /#/(***(*(**,\n*\n*#*,*\n*#*&*/*#*@* ***////&/,/#/*/\n(@(,(@(//.(.(%(.(*/\n/\n/(/\n/&/#/*/,(\n/\n///&/#(@#&#%#.#&#\n#(#,###(#%#%###(# #@#@#\n#.\n (#(&( (#(&(@(@( (((/(#(\n/@*\n* /&/@/%(@.@,&*@*(/*(/#,(.(\n( /#/#/ ***&,\n*@,.,\n,(,**(*.*%*@*/*@*(*&*%*,*.*(*&/(/#/,/@/@/\n/((@/#(((#(#(,((//(\n(,/,/.( /(/,(&/(//( (,/(( ###\n#*(/#/#,#%#/#\n#,#@#,#@# #\n#.#\n#%\n/(@(@(#(*(((,(.(&(/(#(/(./,/%/(*%,\n,\n*/*\n*.*,/%/%/(///,///,* *%*@*,*(,*,.,/,&,\n,.,\n*%*(*** *%*.*,*#*@**/,/ /,///(/#( /@/(//(&( (*(@(((#((/%(#(#(*(,(((@(*(/(%/\n( (%(\n(\n(@#(#%#,# #/#&#,#.#/#(#*#&#.#\n#/#@\n,( (*(/(#(%(*(*(.(*(\n(#/&***\n*,* ,.* /*/,*#* *./@/&*@*&*\n* ,/,.,,,,,/,\n,(,/,/,\n, ,.,,*.* *#*@*@* *#*,*%/(/ /@/,/(/@/*/.(\n///%(\n#/(.#((,(#(#(.(&(,(((./%/\n/,(,(\n((#*#/(@#@#,#@#%###&#,# #.#(#@#*#/# #/# #/\n@(*(#(#(@(((.(.(,(@(%(#*@/@/**,*/,&//*%,/*#/%*(**,/,.,.,,,\n,&,/,,*&,,,#,#,&,\n,&, ,(,\n***.***%*\n*(*@*&*//,/%/ /(/./\n/\n/./#/ (@(#(\n(%(/(%#./ (#(/(.(,(,# #,#,#,#(#\n(&(@((###@###%# #/#.#.#@#*#*#%#,# #.#.#(\n,(.(%(@(\n(\n(,(.(@((( (@/*/(*@*.* *(*.,@*#*.,(,\n,%,(,#,@,@.,.#,&,*,&,*,%,@,.,#,#,., ,@*&*****%*/*%*&*,/(/&/\n**/@/,/\n/#(./ /\n/\n(@(*(####.(&(#(\n(\n#,#&#(# #.#\n#%#*#,(,(,(\n#*#,# #%#&#&#*#.#%#.#,#.#*#@#\n#%##\n&/,(&(/(.( (\n(\n(@(.(\n(*(#/(///@/@/@*\n*#*/*#,@,#, ,\n,..@,%.&,%,\n, ,@,(,&,%,.,/,&*,,.,&,%,&*.*\n*%*\n*,*/*/*/*(///%/(/,/(/,/\n/&/,(,( #(#.#&# #*#%#\n(&#*%,%%%@# ###,#/(\n(@(\n(##@#.###*#@#/#/#@#*#,#/#/#(#,#%#(\n#/%(*(&(*(%(((#(/(/(&(&(#/%/ ///,*\n*@*/*%*.,,,@,(,,././,&,/,*,@,&,#,\n,&,(,\n*,, * **,\n,(, *@*/***.*#*****(*,*%* /%/(#%( #,(%(&(/(,(.#(# #*#,#.#.#@(&%(#@%%%#%@# #(#\n#,# %## #%(##\n#&#.#%#/#&#&#*#%#%###/##\n\n/%(\n(%(\n(,(/(\n(,(,(.(@(((,/// *@(,(%/(*,,%,@,#,#.@,@,..,,@,%,.,/, ,\n,(,/,/*,***#,(*\n,(,(,\n***%*,* *\n*#*,/@(.#\n#,%%%%%&%@# (&# (((\n( #,(\n# (&#/#%#%#.&/%#( #((&(##.#(#(#*#@#(#(#(#.#*#.#@# ### #@###@#@#%\n(/ /.( (%(/(#(,(((/(&(*(@(#(//&/\n/,((*#//*%, ,#/@,*,%,\n,&,,,,.(,@,&,#,@,&,\n,\n, ,(*\n*/,@,(,%* *&**//(*(#%(%\n&/%&#%#%#,#.(##@(*#((@#(#*( #&#&(&(,#/#(%&& &&%.%\n&,&@%.%&%.%\n/&(@#%(@#.#.#(#,#&#@#/#&# #.#*#&\n*/%/%///,/./(/*/&/((&/*(.(((&(%/(/\n(,/&*.,(,&*./#(*#*( /((@*%, *.,#,.*\n,**\n*/,%*\n*/*./*,&,*/.( ( ##%@% %##*( /(/\n/ /&(((((*# #%#,#@(,(#(*(#(((\n(\n(%%/%&&&&\n&@&@%*&.& &#%.#@(((##@((# #\n#\n#\n#\n#&# #/#&#/#\n\n%/@(//@/*(%/ /@/ (*( ( (*( (//./*(@(.#((&,(,\n/&/\n/.* /*(*//(%#/#*(@/#( *.*,*&,*, **/,(%((/./#(.##%&##%.#//#((%,@/&/@#& %*%/(((/#.( (\n(*(@(((/(\n(/#&( %#%%&#&.&&%\n@(&.&(%.#@(@((#/#.# (\n(#(@#*#*#@#\n###@#@\n&/,/./(/*/ /,/ /,/%/./(/,/#/\n( (,(#(@#&/,*(, *\n*/,,,\n,(,*,@*//@(/#\n#,#\n% %/# ,@,@,(*\n*%/&(\n#\n%(%%#&(@/,(*/**\n/%#\n#%# /@/##,#@#\n%&(*(@/ /@( (&( (/(.(&#,@ &(%\n&@&,#%(*/\n(@(@/##%#.###\n###*(##\n( #%###\n#*(@\n#/#///#/%(./,/*/*/(/ ///@/&(&(((#/%(.%,/****@*\n,\n,(/\n%@(,*(,/#*#(#*%%(.#/(///,\n,(,%,&*(*%/ (%###&(&(&#.(\n(@/#(@/,/,(%(%(*(*(%/@( (%/,/@/*(#(.(#(*(%(*(.#%%%&,&.%.#@(%/(/%#*( #&#*###@#*#(#@#/###&#.#&###\n\n./#/@/\n/%/%///*/@///.(./%/#(*(*(\n*.*\n( ((**,(,,,(*%/ ,,,&,&*(*/*\n/&/\n/%(//.*@* ,%,\n,&*#*,/*(\n#%#/(((*(\n(,(\n/*/.( /(/,(#(@(%/%*,*//(/&/\n/@(,(.#&(/(%(* ...

# %%
from func import check_rep
check_rep(cucc, input_string)
# Out:
# Gratulálok! Megoldottad a feladatot!

# %% [markdown]
# ## 3. feladat: írjatok egy függvényt, ami:
# - két listát fogad paraméternek, melyek egy-egy múltbéli dátumot tartalmaznak
# - mindkét lista három elemű az első az évet, a 2. a hónapot a 3. pedig a napot jelöli
# - a függvény visszatérési értéke pedig két szám ami a mai dátum és a bemeneti paraméterként megadott két dátum között eltelt napok száma

# %% [markdown]
# ### Segítség:
# - Figyeljetek rá, hogy Pythonban **nullától kezdődik az indexelés**!
# - Lista elemeire a következő képpen hivatkozunk: lista_valtozo[0] - visszaadja az első elemet, lista_valtozo[1] - visszaadja a második elemet ...
# - 31 napos hónapok: [1, 3, 5, 7, 8, 10, 12]
# - Létezik az in operátor, ami azt vizsgálja meg, hogy egy adott érték eleme e egy másoknak.
# - Pl. "a" in "asd" kifejezés értéke True, ezt listákra is lehet alkalmazni

# %%
input_list1 = [1971, 10, 28]
input_list2 = [1906, 11, 6]

def eltelt_napok(input_list1, input_list2):
    from datetime import date

    d0 = date(2021, 11, 4)
    d1 = date(input_list1[0], input_list1[1], input_list1[2])
    d2 = date(input_list2[0], input_list2[1], input_list2[2])
    delta1 = d0 - d1
    delta2 = d0 - d2
    
    print(delta1.days, delta2.days)

# %%
input_list1 = [1971, 10, 28]
input_list_2 = [1906, 11, 6]

def napok(input_list1, input_list2)
    from datetime import date
    today0=date.today()
    today=[int(today0[0]+today0[1]+today0[2]+today0[3]), int(today0[5]+today0[6]), int(today0[8]+today0[9])]
    rövid=[4,6,9,11]
    hosszú=[1,3,5,7,8,10,12]
    febr=28
    kül1=0
    kül2=0
    if today[1]>input_list1[1]:
        kül1=(today[0]-input_list1[0])*365+int((today[0]-input_list1[0])/4)
# Out:
#   File "<ipython-input-10-9ecb88c84869>", line 4
#     def napok(input_list1, input_list2)
#                                        ^
# SyntaxError: invalid syntax

# %%
from datetime import date
print(date.today())
today0=str(date.today())
today=[int(today0[0]+today0[1]+today0[2]+today0[3]), int(today0[5]+today0[6]), int(today0[8]+today0[9])]
print(today)

input_list1 = [1971, 10, 28]
kül1=(today[0]-input_list1[0])*365+int((today[0]-input_list1[0])/4)
print(kül1)
# Out:
# 2021-11-10
# [2021, 11, 10]
# 18262

# %%
from datetime import date
d0 = date(2008, 8, 18)
d1 = date(2008, 9, 26)
delta = d1 - d0
print(delta.days)
# Out:
# 39

# %%
from func import check_day
check_day(eltelt_napok, input_list1, input_list2)
# Out:
# 18270 42002
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-9334bd3a2b07> in <module>
#       1 from func import check_day
# ----> 2 check_day(eltelt_napok, input_list1, input_list2)
#
# /work/prog1_2021_fall/groups/7/Misi_Katinka_Dorka/func.py in check_day(own_func, inp1, inp2)
#      55 def check_day(own_func, inp1, inp2):
#      56
# ---> 57     out1, out2 = own_func(inp1, inp2)
#      58     out1_, out2_ = day_diff(inp1, inp2)
#      59
#
# TypeError: cannot unpack non-iterable NoneType object

# %% [markdown]
# ## 4. feladat: írjatok egy függvényt, ami:
# - két számot fogad paraméterként
# - visszatérési értéke pedig a két szám legnagyobb közös osztója

# %%
x = 18270
y = 42002

def paprika(x,y):
    if x > y:
        x, y = y, x
    for i in range(1,x+1):
        if x%i == 0 and y%i == 0:
            hcf = i
    return hcf

paprika(x,y)
# Out:
# 2

# %%
from func import check_bcom
check_bcom(paprika, x, y)
# Out:
# Gratulálok! Megoldottad a feladatot!

# %% [markdown]
# ## 5. feladat: írjatok egy függvényt, ami:
# - egy string-et fogad első paraméternek
# - **minden n-edik karakterét tartja csak meg (ahol n a függvény második paramétere), az összes többit kidobja**
# - és ez a módosított string a visszatérési értéke
#
# Figyeljetek rá, hogy Pythonban **nullától kezdődik az indexelés**!

# %%
#NE EZT FRISSÍTSD, KORÁBBI
input_string = cucc(input_string)
n = 2

def cica(input_string, n):
    b=-1
    while b < len(input_string):
        b=b+n
        print(input_string[b])
        
    return print(input_string)

# %%
input_string = cucc(input_string)
n = 2

def cica(input_string, n):
    b=n-1
    kutya=""
    while b < len(input_string):
        kutya=kutya+input_string[b]
        b=b+n
    else:    
        return kutya

# %%
cica("gágkőrejhőűsgjtophpgájgéd", 2)
# Out:
# 'ákrjősjohgjé'

# %%
from func import check_sel
check_sel(cica,input_string,n)
# Out:
# Gratulálok! Megoldottad a feladatot!

# %%
print(cica(input_string, n))
# Out:
# ((((((((((((((((((((((((///***,,,,,,/(/**(//,**(//((#(((##(((/(#((//*///(((/#(##(((###(#############
# (((((((((((((((((((((((#/*,,//((###%((//(*(((/*//((((#((###(((#(/(/((/(##/###(#((###################
# ((((((((((((((((((((##(/**(##&%%%%%#%%#(/#///(*/(/(//////((((((((((((((###(((((#####################
# (((((((((((((((((((%#(/*(((*/((#%###((//*//**/**///////////(//(/(((/////((((((/(((##################
# (((((((((((((((//*(%/,,*///(((//(///****,************//////((((/((((////////(////(##################
# ((((((((((((/**///(.,**/(#(((///**,*,,,,*************///////(/(((((/((//(//(//((/(###(##############
# ((((((((((((///*,,****///////*****,,,,,,,**********//////(///(((((((/(((((((((/(((((################
# (((((((((((/****,*//***//****,,,,,,,,,,,,,*********////////(//(#(#((((((((///(((##(#################
# (((((((((((*//**,/*,*/**,,,,,,,,*,,,,,,,,,*********//////////((((((#/(((((######(((#################
# (((((((((((//*****,**,,,,,,,..,,,,,,,,,,,,********///*////(///(((##((((#########(((#################
# /(((((((((((/////****,,,,,.,.,,,,,,,,,,*,,,,*********/////////((#######(#%%%####((((################
# /(((((((((((////*****,,,,..,,,,,,,,,,*,**,,,***********//#(#(((((#######(%#%%%#####%##(#############
# /((((((((((((//*((/*,,,,.,,.,,,,,,,,,***,*,,,*******/(##%%%%#(#(((#(#(####&%(#((####################
# //((((((((((((///(*/*,,/,,,,,,.,,,,,,,,,**,,,***/((%%&%####(#(#(##(##((##%&&%%&&%%%%/(#(############
# /////////(/((((//(/*,,*/(#(/(*,*,,*,**,***/,,/((#%%%#(////(((####((((((((%%&&&&%&&&%#((#(###########
# /(//(///((((((//((#(,,///*/(/(##(/(***,,*/((//(#%#%#/(%@&@&%%((#((((((((#(%%&&&%@&&%#((###(((#######
# //////////////((((#/*,**,,,,,*/(###%%#,,,**/(#%%#(/(/*/###//###%((//((((((#@&%&&#(/((/######(#(####(
# ////(////////(((/(%/***,,/%(*,###%(#(/,,,,**/(##((#((/(//(((((/((///(((((((#%&&%#(//#(##############
# //////////(//(((**((*,,,*/,,,***///(/**,,,**/(##(((((//(//(((/**////((#(((((###%(((/####(#####(#(###
# /////////(/((((((***(,,,,,,,,,**/(/,,*,,,**/(((((((///////****///((((((#(((##%%%(/(#/########((#((##
# ////////////(/((((/,,*,,,,****,,,,,,,,,,,***//((((((////******//((((((((((####%/*///###(((##((((((##
# /////////(/(((((((((,,*,,,,,,,,,,,,,/,,,,,**/(##(/(#((///****///(((((((########/*//(#####((#(##(####
# /////////////(/((((((,*,,,,,,,,,,,/(*,,.,,,/(((//((#%(##(//////(((((((((###%##(/((######((#(##((##(#
# /////////////(//(((((/,,,,,,,,,,*/((,*****/(#%%%##%((((/((////((((((((##%#####%#(((((#(##((((##((##(
# ///////////////(/((((/,,,,,,,***/((,,,,,*,*/*//(((/((((((((((/(((##((########%##((((((#((#(#(((#((((
# //////////(((/(((((((((/,,,,,**/((,,,,,,,,*//,*///(((/(((#####///(((((#######%##(((((((((((((#(###((
# //////////////(((((((((((,,,,,*/(,,,,,,,,,,/**,*/((((###%%%#((**/(##(((#%###%%##(((((((((((((((##(##
# /////////////((((((((((((/,,,,,*/,,****///////###%%%#((((((((/*//(#((((%%###%#(#(((((((((((((((((#(#
# ///////////(///(/((((((((((,,,,,*/*/,,,,,,,,****///((((((((/////(#(/((%######((*&@%(((((((((((((((##
# /////////(((///(((((((((((((,,,,,**,,,,,,,*****/*(/(((((((/(///(((//(####%#%((/**@@@#((((((((((((((#
# ///////////////((((((((((((((,,,,**,,,,,,,,,*//(/////////(((((((//((#####%%(#****@@@@@((((((((((((#(
# ///(///////(/////(((((((((((((*,,,,,,,,,,,,,,****///////((((###///(#%##%%&(*****/@@@@@@@%(((((((((((
# //////////////////((/(((((((((((,,***,,,,,,,**,*///////(###%#(((((####%%********@@@@@@@@@@@#((((((((
# ////////////(///////////////(((& ***,,,,,*******/////((##%%((((/((##%%(*******/@@@@@@@@@@@@@@@@@&(((
# ///////////////////////(%&@@&&@(  .,,,,,,***///////((#%#(/(((//(##%%(*,*******@@@@@@@@@@@@@@@@@@@@@@
# ///////////////(%&&&@@&@@&&&%&@.    .,,,,,,,,,,,,**/((////(/((###%**,,******/@@@@@@@@@@@@@@@@@@@@@@@
# ///////(%&@@&@@&@@&@&@&&&&&&@@@       .,,,,,**,,,,****///((((##/*,,,,,*****/@@@@@@@@@@@@@@@@@@@@@@@@
# //%&&&&&&&&&@&&@@@&&&&%&%%&@@@*         ,/,,,,,,,,***///((((**,,,,,,,,,***#@@@@@@@@@@@@@@@@@@@@@@@@@
# &&@&&&&&&&&&&&&@&&&&&&&&%@@@@*.          .,(//****,...........,,,,,,,,,**&@@@@@@@@@@@@@@@@@@@@@@@@@@
# &&&%&&&&&&&&&&&&&@@&&&&&&@@@,..          ///. .,         .....,,,,,,,,,*&@@@@@@@@@@@@@&&@@@@@@@@@@@@

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=978e47b7-a961-4dca-a945-499e8b781a34' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
